# %%
import sqlalchemy
from binance import Client
#import python_ta as ta
import numpy as np
import pandas as pd

# %%
symbol ='BTCUSDT'
engine = sqlalchemy.create_engine('sqlite:///'+ symbol + 'stream.db')

# %%
df.Price.plot()
#Fdf.plot()
# Out:
# <AxesSubplot:>

# %%
df=pd.read_sql('BTCUSDT', engine)
#df['sma9'] = df['Price'].rolling(9).mean() # <<<--- SMA 9 --------.
df['sma21'] = df['Price'].rolling(21).mean() # <<<--- SMA 21 --------..
df['sma9'] = df['Price'].rolling(9).mean() # <<<--- SMA 9 --------.
df[-250:].Price.plot(figsize = (20,5))
#df[-250:].sma9.plot()
df[-250:].sma21.plot()
df[-250:].sma9.plot()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
"""
YT : 
NeuralNine
144 k abonnés.

NumPy Full Python Course - Data Science Fundamentals

https://www.youtube.com/watch?v=4c_mwnYdbhQ
https://www.youtube.com/watch?v=4c_mwnYdbhQ

"""
numbers = np.random.randint(100, size=(2,3,4))

# %%
print(numbers)

# %%
#numbers = np.random.choice([10,20,0,40,50,60], size=(5,10))
numbers = np.random.choice([10,20,0,40,50,60], size=(1_000_000,32))  # 1 000 000 lignes  et 32 colonnes   ....

# %%
print(numbers)
# Out:
# [[40 10 40 ... 50 60  0]
#  [ 0  0 40 ... 40 20 10]
#  [60 50  0 ... 50 20 20]
#  ...
#  [20 10 20 ...  0 10  0]
#  [40  0 40 ... 50 50 40]
#  [40 10  0 ... 20  0 40]]

# %%
np.save("test_save_format.npy", numbers)  # 1.7s pour  1 000 000 lignes...

# %%
a= np.load("test_save_format.npy")    # 1.7s pour  1 000 000 lignes...

# %%
print(a)

# %%
np.savetxt("test_save_format.csv", numbers) # 40s pour 1 000 000 lignes ...

# %%
b= np.loadtxt("test_save_format.csv")   # 40s pour 1 000 000 lignes ...

# %%
"""
Code from 
YT :

Medallion Data Science
5,82 k abonnés

The BEST way to store data in python & pandas.. spoiler: it's not CSV

https://www.youtube.com/watch?v=u4rsA5ZiTls&t=74s
https://www.youtube.com/watch?v=u4rsA5ZiTls&t=74s

"""

# %%
pip install pyarrow
# Out:
# Collecting pyarrowNote: you may need to restart the kernel to use updated packages.
#   Downloading pyarrow-8.0.0-cp37-cp37m-win_amd64.whl (17.8 MB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\user\miniconda3\lib\site-packages (from pyarrow) (1.21.4)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-8.0.0

# %%
pip install fastparquet
# Out:
# Collecting fastparquet
#   Downloading fastparquet-0.8.1-cp37-cp37m-win_amd64.whl (611 kB)
# Collecting cramjam>=2.3.0
#   Downloading cramjam-2.5.0-cp37-none-win_amd64.whl (993 kB)
# Collecting fsspec
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
# Requirement already satisfied: numpy>=1.18 in c:\users\user\miniconda3\lib\site-packages (from fastparquet) (1.21.4)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\user\miniconda3\lib\site-packages (from fastparquet) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\miniconda3\lib\site-packages (from pandas>=1.1.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\miniconda3\lib\site-packages (from pandas>=1.1.0->fastparquet) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\miniconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.1.0->fastparquet) (1.16.0)
# Installing collected packages: fsspec, cramjam, fastparquet
# Successfully installed cramjam-2.5.0 fastparquet-0.8.1 fsspec-2022.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# pandas-data-storage-compare.py
# pandas-data-storage-compare.py
# pandas-data-storage-compare.py

import pandas as pd
import numpy as np

def get_dataset(size):
    # Create Fake Dataset
    df = pd.DataFrame()
    df['size'] = np.random.choice(['big','medium','small'], size)
    df['age'] = np.random.randint(1, 50, size)
    df['team'] = np.random.choice(['red','blue','yellow','green'], size)
    df['win'] = np.random.choice(['yes','no'], size)
    dates = pd.date_range('2020-01-01', '2022-12-31')
    df['date'] = np.random.choice(dates, size)
    df['prob'] = np.random.uniform(0, 1, size)
    return df

def set_dtypes(df):
    df['size'] = df['size'].astype('category')
    df['team'] = df['team'].astype('category')
    df['age'] = df['age'].astype('int16')
    df['win'] = df['win'].map({'yes':True, 'no': False})
    df['prob'] = df['prob'].astype('float32')
    return df
#. print('Reading and writing CSV')
#. df = get_dataset(5_000_000)
#. df = set_dtypes(df)
#. %time df.to_csv('test.csv')
#. %time df_csv = pd.read_csv('test.csv')

# print('Reading and writing Pickle')
# df = get_dataset(5_000_000)
# df = set_dtypes(df)
# %time df.to_pickle('test.pickle')
# %time df_pickle = pd.read_pickle('test.pickle')

print('Reading and writing Parquet')
df = get_dataset(5_000_000)
df = set_dtypes(df)
# %time df.to_parquet('test.parquet')
# %time df_parquet = pd.read_parquet('test.parquet')

print('Reading and writing Feather')
df = get_dataset(5_000_000)
df = set_dtypes(df)
# %time df.to_feather('test.feather')
# %time df_feather = pd.read_feather('test.feather')

print('Reading and writing np (NP) format')
df = get_dataset(5_000_000)
df = set_dtypes(df)
# %time np.save("test_save_np_format.npy", df)
# %time a= np.load("test_save_np_format.npy")

# %%
print('Reading and writing Pickle')
df = get_dataset(5_000_000)
df = set_dtypes(df)
# %time df.to_pickle('test.pickle')
# %time df_pickle = pd.read_pickle('test.pickle')
# Out:
# Reading and writing Pickle
# Wall time: 234 ms
# Wall time: 172 ms

# %%
print('Reading and writing np (NP) format')
df = get_dataset(5_000_000)
df = set_dtypes(df)
# %time np.save("test_save_np_format.npy", df)
# %time a= np.load("test_save_np_format.npy")

np.save("test_save_np_format.npy", df)
a= np.load("test_save_np_format.npy")
# Out:
# Reading and writing np (NP) format
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8688/1548220354.py in <module>
#       6
#       7 np.save("test_save_np_format.npy", df)
# ----> 8 a= np.load("test_save_np_format.npy")
#
# c:\Users\user\miniconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     439             else:
#     440                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 441                                          pickle_kwargs=pickle_kwargs)
#     442         else:
#     443             # Try a pickle
#
# c:\Users\user\miniconda3\lib\site-packages\numpy\lib\format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     741         # The array contained Python objects. We need to unpickle the data.
#     742         if not allow_pickle:
# --> 743             raise ValueError("Object arrays cannot be loaded when "
#     744                              "allow_pickle=False")
#     745         if pickle_kwargs is None:
#
# ValueError: Object arrays cannot be loaded when allow_pickle=False

# %%
#         -------------      MATPLOTLIB  ANIMATION     --------------------
#         -------------      MATPLOTLIB  ANIMATION     --------------------
#         -------------      MATPLOTLIB  ANIMATION     --------------------
#         -------------      MATPLOTLIB  ANIMATION     --------------------
"""
YT : 
NeuralNine
144 k abonnés.

Vid : Matplotlib Animations in Python

https://www.youtube.com/watch?v=7RgoHTMbp4A&t=3s
https://www.youtube.com/watch?v=7RgoHTMbp4A&t=3s
https://www.youtube.com/watch?v=7RgoHTMbp4A&t=3s

"""

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\user\miniconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\user\miniconda3\lib\site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\user\miniconda3\lib\site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\user\miniconda3\lib\site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\miniconda3\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\miniconda3\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import random

# %%
x_values=[]
y_values=[]

# %%
#from statistics import LinearRegression

reg = LinearRegression()

# %%
from matplotlib import pyplot as plt
# from matplotlib.animation import FuncAnimation
# fig = plt.figure(figsize = (10,10))
# to run GUI event loop
# here we are creating sub plots
# ax1 = fig.add_subplot(1,1,1)

pnum=5  # 20 < ---    nombre de points  ...

for i in range(2):
    #axes[0,1].clear
    plt.clf()  # <- --- clear figure ...
    x_values.append(random.randint(0,pnum))
    y_values.append(random.randint(0,pnum))

    x = np.array(x_values)
    x = x.reshape(-1, 1)

    y = np.array(y_values)
    y = y.reshape(-1, 1)

    # if i % 5 ==0:
    reg.fit(x, y)  # <<---   Calcul the regression Line  ...  

    plt.xlim(0,pnum)
    plt.ylim(0,pnum)
    plt.scatter(x_values, y_values, color='black')
        #ax1.plot(x,y)
    plt.plot(list(range(pnum)), reg.predict (np.array([x for x in range(pnum)]).reshape(-1,1))) # <<---  Plot the regression line  ...
        #fig.add_subplot()
    plt.pause(0.001)
      

# animation = FuncAnimation(fig, ani, interval = 100)
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation

fig = plt.figure(figsize = (10,10))
# to run GUI event loop
# here we are creating sub plots
ax1 = fig.add_subplot(1,1,1)

def ani(d):
  for i in range(20):
    #axes[0,1].clear
    x_values.append(random.randint(0,20))
    y_values.append(random.randint(0,20))

    x = np.array(x_values)
    x = x.reshape(-1, 1)

    y = np.array(y_values)
    y = y.reshape(-1, 1)

    if i % 5 ==0:
        reg.fit(x, y)  # <<---   Calcul the regression Line  ...  

        #plt.xlim(0,20)
        #plt.ylim(0,20)
        #plt.scatter(x_values, y_values, color='black')
        ax1.plot(x,y)
        #plt.plot(list(range(20)), reg.predict (np.array([x for x in range(20)]).reshape(-1,1))) # <<---  Plot the regression line  ...
        #fig.add_subplot()
      # plt.pause(0.001)
      

animation = FuncAnimation(fig, ani, 
                          interval = 100)
plt.show()

# %%
fig = plt.figure(figsize = (10,10))

plt.show()

# %%
pip install drawnow
# Out:
# Collecting drawnow
#   Downloading drawnow-0.72.5-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: matplotlib>=1.5 in c:\users\user\miniconda3\lib\site-packages (from drawnow) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\miniconda3\lib\site-packages (from matplotlib>=1.5->drawnow) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\miniconda3\lib\site-packages (from matplotlib>=1.5->drawnow) (9.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\miniconda3\lib\site-packages (from matplotlib>=1.5->drawnow) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\miniconda3\lib\site-packages (from matplotlib>=1.5->drawnow) (4.33.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\miniconda3\lib\site-packages (from matplotlib>=1.5->drawnow) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\miniconda3\lib\site-packages (from matplotlib>=1.5->drawnow) (3.0.8)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\miniconda3\lib\site-packages (from matplotlib>=1.5->drawnow) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\miniconda3\lib\site-packages (from matplotlib>=1.5->drawnow) (2.8.2)
# Requirement already satisfied: typing-extensions in c:\users\user\miniconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib>=1.5->drawnow) (4.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.5->drawnow) (1.16.0)
# Installing collected packages: drawnow
# Successfully installed drawnow-0.72.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bokeh
# Out:
# Collecting bokeh
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Collecting PyYAML>=3.10
#   Downloading PyYAML-6.0-cp37-cp37m-win_amd64.whl (153 kB)
# Requirement already satisfied: tornado>=5.1 in c:\users\user\miniconda3\lib\site-packages (from bokeh) (6.1)
# Collecting Jinja2>=2.9
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\user\miniconda3\lib\site-packages (from bokeh) (4.0.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\user\miniconda3\lib\site-packages (from bokeh) (21.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\user\miniconda3\lib\site-packages (from bokeh) (9.1.0)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\user\miniconda3\lib\site-packages (from bokeh) (1.21.4)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-win_amd64.whl (17 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\miniconda3\lib\site-packages (from packaging>=16.8->bokeh) (3.0.8)
# Installing collected packages: MarkupSafe, PyYAML, Jinja2, bokeh
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.1 PyYAML-6.0 bokeh-2.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from bokeh.plotting import curdoc, figure

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.cos(x)

plt.ion()

figure, ax = plt.subplots(figsize=(8,6))
line1, = ax.plot(x, y)

plt.title("Dynamic Plot of sinx",fontsize=25)

plt.xlabel("X",fontsize=18)
plt.ylabel("sinX",fontsize=18)

for p in range(3):
    updated_y = np.cos(x-0.05*p)
    
    line1.set_xdata(x)
    line1.set_ydata(updated_y)
    
    figure.canvas.draw()
    
    figure.canvas.flush_events()
    time.sleep(0.1)

# %%
from matplotlib import pyplot as plt
  
x = []
y = []
  
for i in range(100):
    x.append(i)
    y.append(i)
  
    # Mention x and y limits to define their range
    plt.xlim(0, 100)
    plt.ylim(0, 100)
      
    # Ploting graph
    plt.plot(x, y, color = 'green')
    plt.pause(0.01)
  
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
import random
import numpy as np
  
x = []
y = []
colors = []
fig = plt.figure(figsize=(7,5))
ax1 = fig.add_subplot(1,1,1)

def animation_func(i):
    for i in range(1,10):
        x.append(random.randint(0,100))
        y.append(random.randint(0,100))
    #colors.append(np.random.rand(1))
    #area = random.randint(0,30) * random.randint(0,30)
    #plt.xlim(0,100)
    #plt.ylim(0,100)
    #plt.scatter(x, y, c = colors, s = area, alpha = 0.5)
    
    #ax1.plot.scatter(x, y, c = colors, alpha = 0.5) 
    ax1.clear()   
    ax1.plot(x, y)
  
animation = FuncAnimation(fig, animation_func, 
                          interval = 100)
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np

x = []
y = []

figure, ax = plt.subplots()

# Setting limits for x and y axis
ax.set_xlim(0, 100)
ax.set_ylim(0, 12)

# Since plotting a single graph
line, = ax.plot(0, 0)

def animation_function(i):
	x.append(i * 15)
	y.append(i)

	line.set_xdata(x)
	line.set_ydata(y)
	return line,

animation = FuncAnimation(figure,
						func = animation_function,
						frames = np.arange(0, 10, 0.1),
						interval = 10)


def animate(i):
    xs =[]
    ys =[]
    for line in lines:
                                
ani = animation.FuncAnimation(fig, animate, interval = 1000)
plt.show()
