# %%
"""
   - ------   BINANCE WEBSOCKET ERROR  -------
      -----------  TEST LIVE DATA and DATA BASE --------
              ( - ICI CA MARCHE - )
YT :::
Algovibes
39,3 k abonnés

FIX ERROR BINANCE WEBSOCKET ...

How to get LIVE cryptocurrency data with Python using the 
Binance API / 
ERROR FIXING
https://www.youtube.com/watch?v=OX5eDJDtqhc
https://www.youtube.com/watch?v=OX5eDJDtqhc

YT  :::
INFINITY ALEX  ( - ICI CA MARCHE - )
https://www.youtube.com/watch?v=ml3jGc8RqMk
https://www.youtube.com/watch?v=ml3jGc8RqMk

"""

# %%
# !pip install python-binance

# %%
# !pip install asyncio

# %%
# DOC ::: https://python-binance.readthedocs.io/en/latest/websockets.html
import asyncio
from binance import AsyncClient, BinanceSocketManager
import pandas as pd

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
symbol ='BTCUSDT'

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('sqlite:///'+ symbol + 'stream.db')

# %%
def createframe(res):
    df = pd.DataFrame([res])
    df = df[['s', 'E', 'p']]
    df.columns = ['symbol', 'Time', 'Price']

    df.Price = df.Price.astype(float)
    df.Time = pd.to_datetime(df.Time, unit='ms')

    return df

# %%
# DOC ::: https://python-binance.readthedocs.io/en/latest/websockets.html
#import asyncio
#from binance import AsyncClient, BinanceSocketManager
async def main():
    client = await AsyncClient.create()
    bm = BinanceSocketManager(client)
    # start any sockets here, i.e a trade socket
    # ts = bm.trade_socket('BTCUSDT')
    ts = bm.trade_socket(symbol)

    # then start receiving messages
    async with ts as tscm:
        while True:
            res = await tscm.recv()
            df = createframe(res)
            df.to_sql(symbol, engine, if_exists='append', index=False)
            #.print(res)
            print(df)

    await client.close_connection()

#if __name__ == "__main__":

#    loop = asyncio.get_event_loop()
#    loop.run_until_complete(main())

# %%
if __name__ == "__main__":

    loop = asyncio.get_event_loop()
    loop.run_until_complete(main())
# Out:
#     symbol                    Time    Price
# 0  BTCUSDT 2022-05-01 09:42:50.695  37947.0
#     symbol                    Time     Price
# 0  BTCUSDT 2022-05-01 09:42:50.948  37946.99
#     symbol                    Time     Price
# 0  BTCUSDT 2022-05-01 09:42:51.615  37946.99
#     symbol                    Time     Price
# 0  BTCUSDT 2022-05-01 09:42:51.615  37946.99
#     symbol                    Time     Price
# 0  BTCUSDT 2022-05-01 09:42:51.615  37946.99
#     symbol                    Time     Price
# 0  BTCUSDT 2022-05-01 09:42:51.647  37946.99
#     symbol                    Time     Price
# 0  BTCUSDT 2022-05-01 09:42:51.647  37946.99
#     symbol                    Time     Price
# 0  BTCUSDT 2022-05-01 09:42:51.686  37946.95
#     symbol                    Time     Price
# 0  BTCUSDT 2022-05-01 09:42:51.840  37946.95
#     symbol                    Time     Price
# 0  BTCUSDT 2022-05-01 09:42:51.891  37946.95
#     symbol                    Time     Price
# ...
